# %%
import pandas as pd

# %% [markdown]
# # **TASK 3**

# %% [markdown]
# # 1) Import and Process Rembrandt Pyradiomics Data

# %% [markdown]
# ## Load and clean data

# %%
test=pd.read_csv('/content/drive/MyDrive/HIDS_7009/7009_Project/7009project_task1_youngmin.csv')
test.head()
# Out:
#                   id diagnostics_Versions_PyRadiomics  \
# 0  HF1097_1992.11.09                           v3.0.1
# 1  HF1150_1993.03.10                           v3.0.1
# 2  HF1078_1992.09.07                           v3.0.1
# 3  HF1000_1991.12.20                           v3.0.1
# 4  HF0920_1991.06.14                           v3.0.1
#
#   diagnostics_Versions_Numpy diagnostics_Versions_SimpleITK  \
# 0                     1.25.2                          2.3.1
# 1                     1.25.2                          2.3.1
# 2                     1.25.2                          2.3.1
# 3                     1.25.2                          2.3.1
# 4                     1.25.2                          2.3.1
#
#   diagnostics_Versions_PyWavelet diagnostics_Versions_Python  \
# 0                          1.6.0                     3.10.12
# 1                          1.6.0                     3.10.12
# 2                          1.6.0                     3.10.12
# ...

# %%
test['id']=test['id'].str.split('_').str[0]
test
# Out:
#         id diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# 0   HF1097                           v3.0.1                     1.25.2
# 1   HF1150                           v3.0.1                     1.25.2
# 2   HF1078                           v3.0.1                     1.25.2
# 3   HF1000                           v3.0.1                     1.25.2
# 4   HF0920                           v3.0.1                     1.25.2
# ..     ...                              ...                        ...
# 59  HF1587                           v3.0.1                     1.25.2
# 60  HF1551                           v3.0.1                     1.25.2
# 61  HF1538                           v3.0.1                     1.25.2
# 62  HF1517                           v3.0.1                     1.25.2
# 63  HF1560                           v3.0.1                     1.25.2
#
#    diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# ...

# %%
# Check columns in test df
columns_list = test.columns.tolist()
for column in columns_list:
    print(column)
# Out:
# id
# diagnostics_Versions_PyRadiomics
# diagnostics_Versions_Numpy
# diagnostics_Versions_SimpleITK
# diagnostics_Versions_PyWavelet
# diagnostics_Versions_Python
# diagnostics_Configuration_Settings
# diagnostics_Configuration_EnabledImageTypes
# diagnostics_Image-original_Hash
# diagnostics_Image-original_Dimensionality
# diagnostics_Image-original_Spacing
# diagnostics_Image-original_Size
# diagnostics_Image-original_Mean
# diagnostics_Image-original_Minimum
# diagnostics_Image-original_Maximum
# diagnostics_Mask-original_Hash
# diagnostics_Mask-original_Spacing
# diagnostics_Mask-original_Size
# diagnostics_Mask-original_BoundingBox
# diagnostics_Mask-original_VoxelNum
# diagnostics_Mask-original_VolumeNum
# diagnostics_Mask-original_CenterOfMassIndex
# diagnostics_Mask-original_CenterOfMass
# original_shape_Elongation
# original_shape_Flatness
# original_shape_LeastAxisLength
# original_shape_MajorAxisLength
# original_shape_Maximum2DDiameterColumn
# ...

# %%
# Filter columns matching to the tcga data for further processing.
columns_to_keep=[
    'diagnostics_Image-original_Maximum',
    'diagnostics_Image-original_Mean',
    'diagnostics_Mask-original_VolumeNum',
    'diagnostics_Mask-original_VoxelNum',
    'original_firstorder_10Percentile',
    'original_firstorder_90Percentile',
    'original_firstorder_Energy',
    'original_firstorder_Entropy',
    'original_firstorder_InterquartileRange',
    'original_firstorder_Kurtosis',
    'original_firstorder_Maximum',
    'original_firstorder_Mean',
    'original_firstorder_MeanAbsoluteDeviation',
    'original_firstorder_Median',
    'original_firstorder_Minimum',
    'original_firstorder_Range',
    'original_firstorder_RobustMeanAbsoluteDeviation',
    'original_firstorder_RootMeanSquared',
    'original_firstorder_Skewness',
    'original_firstorder_TotalEnergy',
    'original_firstorder_Uniformity',
    'original_firstorder_Variance',
    'original_glcm_Autocorrelation',
    'original_glcm_ClusterProminence',
    'original_glcm_ClusterShade',
    'original_glcm_ClusterTendency',
    'original_glcm_Contrast',
    'original_glcm_Correlation',
    'original_glcm_DifferenceAverage',
    'original_glcm_DifferenceEntropy',
    'original_glcm_DifferenceVariance',
    'original_glcm_Id',
    'original_glcm_Idm',
    'original_glcm_Idmn',
    'original_glcm_Idn',
    'original_glcm_Imc1',
    'original_glcm_Imc2',
    'original_glcm_InverseVariance',
    'original_glcm_JointAverage',
    'original_glcm_JointEnergy',
    'original_glcm_JointEntropy',
    'original_glcm_MCC',
    'original_glcm_MaximumProbability',
    'original_glcm_SumAverage',
    'original_glcm_SumEntropy',
    'original_glcm_SumSquares',
    'original_gldm_DependenceEntropy',
    'original_gldm_DependenceNonUniformity',
    'original_gldm_DependenceNonUniformityNormalized',
    'original_gldm_DependenceVariance',
    'original_gldm_GrayLevelNonUniformity',
    'original_gldm_GrayLevelVariance',
    'original_gldm_HighGrayLevelEmphasis',
    'original_gldm_LargeDependenceEmphasis',
    'original_gldm_LargeDependenceHighGrayLevelEmphasis',
    'original_gldm_LargeDependenceLowGrayLevelEmphasis',
    'original_gldm_LowGrayLevelEmphasis',
    'original_gldm_SmallDependenceEmphasis',
    'original_gldm_SmallDependenceHighGrayLevelEmphasis',
    'original_gldm_SmallDependenceLowGrayLevelEmphasis',
    'original_glrlm_GrayLevelNonUniformity',
    'original_glrlm_GrayLevelNonUniformityNormalized',
    'original_glrlm_GrayLevelVariance',
    'original_glrlm_HighGrayLevelRunEmphasis',
    'original_glrlm_LongRunEmphasis',
    'original_glrlm_LongRunHighGrayLevelEmphasis',
    'original_glrlm_LongRunLowGrayLevelEmphasis',
    'original_glrlm_LowGrayLevelRunEmphasis',
    'original_glrlm_RunEntropy',
    'original_glrlm_RunLengthNonUniformity',
    'original_glrlm_RunLengthNonUniformityNormalized',
    'original_glrlm_RunPercentage',
    'original_glrlm_RunVariance',
    'original_glrlm_ShortRunEmphasis',
    'original_glrlm_ShortRunHighGrayLevelEmphasis',
    'original_glrlm_ShortRunLowGrayLevelEmphasis',
    'original_glszm_GrayLevelNonUniformity',
    'original_glszm_GrayLevelNonUniformityNormalized',
    'original_glszm_GrayLevelVariance',
    'original_glszm_HighGrayLevelZoneEmphasis',
    'original_glszm_LargeAreaEmphasis',
    'original_glszm_LargeAreaHighGrayLevelEmphasis',
    'original_glszm_LargeAreaLowGrayLevelEmphasis',
    'original_glszm_LowGrayLevelZoneEmphasis',
    'original_glszm_SizeZoneNonUniformity',
    'original_glszm_SizeZoneNonUniformityNormalized',
    'original_glszm_SmallAreaEmphasis',
    'original_glszm_SmallAreaHighGrayLevelEmphasis',
    'original_glszm_SmallAreaLowGrayLevelEmphasis',
    'original_glszm_ZoneEntropy',
    'original_glszm_ZonePercentage',
    'original_glszm_ZoneVariance',
    'original_ngtdm_Busyness',
    'original_ngtdm_Coarseness',
    'original_ngtdm_Complexity',
    'original_ngtdm_Contrast',
    'original_ngtdm_Strength',
    'original_shape_Elongation',
    'original_shape_Flatness',
    'original_shape_LeastAxisLength',
    'original_shape_MajorAxisLength',
    'original_shape_Maximum2DDiameterColumn',
    'original_shape_Maximum2DDiameterRow',
    'original_shape_Maximum2DDiameterSlice',
    'original_shape_Maximum3DDiameter',
    'original_shape_MeshVolume',
    'original_shape_MinorAxisLength',
    'original_shape_Sphericity',
    'original_shape_SurfaceArea',
    'original_shape_SurfaceVolumeRatio',
    'original_shape_VoxelVolume'
]

# %%
test_filtered=test[columns_to_keep].copy()
test_filtered.head()
# Out:
#    diagnostics_Image-original_Maximum  diagnostics_Image-original_Mean  \
# 0                              1671.0                       115.662469
# 1                              2242.0                       103.005568
# 2                               841.0                        99.133747
# 3                              1061.0                       108.419266
# 4                              1277.0                       125.274147
#
#    diagnostics_Mask-original_VolumeNum  diagnostics_Mask-original_VoxelNum  \
# 0                                   41                                6602
# 1                                   91                                7074
# 2                                   58                               35607
# 3                                    1                               33927
# 4                                   16                               51894
#
#    original_firstorder_10Percentile  original_firstorder_90Percentile  \
# ...

# %%
# Check for missing values
missing_total=test_filtered.isnull().sum().sum()
missing_total
# Out:
# 0

# %%
# Drop ID column
test_final=test_filtered
test_final.head()
# Out:
#    diagnostics_Image-original_Maximum  diagnostics_Image-original_Mean  \
# 0                              1671.0                       115.662469
# 1                              2242.0                       103.005568
# 2                               841.0                        99.133747
# 3                              1061.0                       108.419266
# 4                              1277.0                       125.274147
#
#    diagnostics_Mask-original_VolumeNum  diagnostics_Mask-original_VoxelNum  \
# 0                                   41                                6602
# 1                                   91                                7074
# 2                                   58                               35607
# 3                                    1                               33927
# 4                                   16                               51894
#
#    original_firstorder_10Percentile  original_firstorder_90Percentile  \
# ...

# %% [markdown]
# ## Scale Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
test_final_scaled=scaler.fit_transform(test_final)
test_final_scaled
# Out:
# array([[ 0.411428  , -0.09357304,  0.05582739, ..., -0.43117074,
#          0.6294826 , -0.69102113],
#        [ 1.21861505, -0.33170897,  1.39904277, ..., -0.26677692,
#          0.92666501, -0.67149221],
#        [-0.76189118, -0.40455616,  0.51252062, ...,  2.3360763 ,
#         -0.11895252,  0.50905591],
#        ...,
#        [-0.74210025, -0.63371396,  3.17208708, ...,  0.30963033,
#          0.52191415, -0.47529275],
#        [-0.49047277, -0.40923764, -0.56205169, ..., -1.34708141,
#          2.87426218, -0.9342224 ],
#        [-0.08193151, -0.09518068,  2.33929354, ...,  0.6432248 ,
#          0.6983413 , -0.45295034]])

# %%
test_final_scaled.shape
# Out:
# (64, 111)

# %%
test_final=pd.DataFrame(test_final_scaled, columns=columns_to_keep)
test_final
# Out:
#     diagnostics_Image-original_Maximum  diagnostics_Image-original_Mean  \
# 0                             0.411428                        -0.093573
# 1                             1.218615                        -0.331709
# 2                            -0.761891                        -0.404556
# 3                            -0.450891                        -0.229852
# 4                            -0.145545                         0.087268
# ..                                 ...                              ...
# 59                           -0.709587                        -0.724019
# 60                           -0.436755                        -0.641042
# 61                           -0.742100                        -0.633714
# 62                           -0.490473                        -0.409238
# 63                           -0.081932                        -0.095181
#
#     diagnostics_Mask-original_VolumeNum  diagnostics_Mask-original_VoxelNum  \
# ...

# %% [markdown]
# ## Create another test data with top 30 feature as did in training process.

# %% [markdown]
# 1) Random Forest

# %%
file_path='/content/drive/MyDrive/HIDS_7009/7009_Project/top_30_features_rf.txt'
with open(file_path, "r") as file:
  lines=file.read().splitlines()

print(lines)
# Out:
# ['diagnostics_Mask-original_VolumeNum', 'original_shape_Sphericity', 'original_firstorder_TotalEnergy', 'original_shape_SurfaceVolumeRatio', 'original_firstorder_Energy', 'original_glrlm_RunLengthNonUniformity', 'original_firstorder_Minimum', 'original_firstorder_Kurtosis', 'original_glrlm_RunEntropy', 'original_firstorder_10Percentile', 'original_glszm_SmallAreaEmphasis', 'original_glcm_Imc1', 'original_gldm_LargeDependenceHighGrayLevelEmphasis', 'original_ngtdm_Coarseness', 'original_glszm_GrayLevelNonUniformity', 'original_glcm_Correlation', 'original_shape_Maximum2DDiameterSlice', 'original_shape_LeastAxisLength', 'original_shape_Maximum3DDiameter', 'original_shape_Maximum2DDiameterColumn', 'original_glszm_SizeZoneNonUniformityNormalized', 'original_firstorder_90Percentile', 'original_glrlm_LongRunHighGrayLevelEmphasis', 'original_gldm_DependenceNonUniformity', 'original_glcm_MCC', 'diagnostics_Mask-original_VoxelNum', 'original_firstorder_RootMeanSquared', 'original_glrlm_GrayLe
# ...

# %%
rf_top30_features=lines
rf_top30_features
# Out:
# ['diagnostics_Mask-original_VolumeNum',
#  'original_shape_Sphericity',
#  'original_firstorder_TotalEnergy',
#  'original_shape_SurfaceVolumeRatio',
#  'original_firstorder_Energy',
#  'original_glrlm_RunLengthNonUniformity',
#  'original_firstorder_Minimum',
#  'original_firstorder_Kurtosis',
#  'original_glrlm_RunEntropy',
#  'original_firstorder_10Percentile',
#  'original_glszm_SmallAreaEmphasis',
#  'original_glcm_Imc1',
#  'original_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'original_ngtdm_Coarseness',
#  'original_glszm_GrayLevelNonUniformity',
#  'original_glcm_Correlation',
#  'original_shape_Maximum2DDiameterSlice',
#  'original_shape_LeastAxisLength',
#  'original_shape_Maximum3DDiameter',
#  'original_shape_Maximum2DDiameterColumn',
#  'original_glszm_SizeZoneNonUniformityNormalized',
#  'original_firstorder_90Percentile',
#  'original_glrlm_LongRunHighGrayLevelEmphasis',
#  'original_gldm_DependenceNonUniformity',
#  'original_glcm_MCC',
# ...

# %%
test_top30_rf = test_final[rf_top30_features]

test_top30_rf
# Out:
#     diagnostics_Mask-original_VolumeNum  original_shape_Sphericity  \
# 0                              0.055827                  -0.810665
# 1                              1.399043                  -0.961908
# 2                              0.512521                  -0.918380
# 3                             -1.018745                   1.467494
# 4                             -0.615780                   0.091386
# ..                                  ...                        ...
# 59                            -0.481459                   0.190854
# 60                            -0.374002                  -0.596648
# 61                             3.172087                  -0.954630
# 62                            -0.562052                  -0.732886
# 63                             2.339294                  -1.065598
#
#     original_firstorder_TotalEnergy  original_shape_SurfaceVolumeRatio  \
# 0                         -0.603973                           0.629483
# ...

# %% [markdown]
# 2) Decision Tree

# %%
file_path='/content/drive/MyDrive/HIDS_7009/7009_Project/top_30_features_dt.txt'
with open(file_path, "r") as file:
  lines=file.read().splitlines()

print(lines)
# Out:
# ['diagnostics_Mask-original_VolumeNum', 'original_glcm_MCC', 'original_glrlm_RunLengthNonUniformity', 'original_shape_SurfaceVolumeRatio', 'original_shape_SurfaceArea', 'original_glszm_ZoneEntropy', 'original_ngtdm_Busyness', 'original_shape_Elongation', 'original_glszm_LargeAreaEmphasis', 'original_ngtdm_Strength', 'original_firstorder_10Percentile', 'original_shape_MajorAxisLength', 'original_gldm_LowGrayLevelEmphasis', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'original_shape_Flatness', 'original_glszm_HighGrayLevelZoneEmphasis', 'original_glcm_Idmn', 'diagnostics_Image-original_Maximum', 'original_firstorder_Mean', 'original_firstorder_MeanAbsoluteDeviation', 'original_glcm_DifferenceVariance', 'original_glcm_Id', 'original_glcm_Idm', 'original_firstorder_Energy', 'original_glcm_Idn', 'original_glcm_Imc1', 'original_glcm_Imc2', 'original_glcm_InverseVariance', 'original_glcm_JointAverage', 'original_glcm_JointEnergy']

# %%
dt_top30_features=lines
dt_top30_features
# Out:
# ['diagnostics_Mask-original_VolumeNum',
#  'original_glcm_MCC',
#  'original_glrlm_RunLengthNonUniformity',
#  'original_shape_SurfaceVolumeRatio',
#  'original_shape_SurfaceArea',
#  'original_glszm_ZoneEntropy',
#  'original_ngtdm_Busyness',
#  'original_shape_Elongation',
#  'original_glszm_LargeAreaEmphasis',
#  'original_ngtdm_Strength',
#  'original_firstorder_10Percentile',
#  'original_shape_MajorAxisLength',
#  'original_gldm_LowGrayLevelEmphasis',
#  'original_glrlm_ShortRunHighGrayLevelEmphasis',
#  'original_shape_Flatness',
#  'original_glszm_HighGrayLevelZoneEmphasis',
#  'original_glcm_Idmn',
#  'diagnostics_Image-original_Maximum',
#  'original_firstorder_Mean',
#  'original_firstorder_MeanAbsoluteDeviation',
#  'original_glcm_DifferenceVariance',
#  'original_glcm_Id',
#  'original_glcm_Idm',
#  'original_firstorder_Energy',
#  'original_glcm_Idn',
#  'original_glcm_Imc1',
#  'original_glcm_Imc2',
#  'original_glcm_InverseVariance',
#  'original_glcm_JointAverage',
# ...

# %%
test_top30_dt=test_final.filter(items=dt_top30_features)
test_top30_dt
# Out:
#     diagnostics_Mask-original_VolumeNum  original_glcm_MCC  \
# 0                              0.055827           0.474977
# 1                              1.399043           0.419437
# 2                              0.512521           1.428096
# 3                             -1.018745          -0.837205
# 4                             -0.615780          -0.100382
# ..                                  ...                ...
# 59                            -0.481459           0.064855
# 60                            -0.374002           0.579574
# 61                             3.172087          -0.906440
# 62                            -0.562052           1.833270
# 63                             2.339294          -0.938498
#
#     original_glrlm_RunLengthNonUniformity  original_shape_SurfaceVolumeRatio  \
# 0                               -0.556634                           0.629483
# 1                               -0.593809                           0.926665
# ...

# %% [markdown]
# 3) XGB

# %%
file_path='/content/drive/MyDrive/HIDS_7009/7009_Project/top_50_features_xgb.txt'
with open(file_path, "r") as file:
  lines=file.read().splitlines()

print(lines)
# Out:
# ['original_firstorder_10Percentile', 'original_glrlm_RunLengthNonUniformity', 'original_glszm_SmallAreaHighGrayLevelEmphasis', 'original_firstorder_Range', 'original_glrlm_GrayLevelNonUniformityNormalized', 'original_glcm_Imc2', 'original_glszm_SizeZoneNonUniformity', 'diagnostics_Mask-original_VolumeNum', 'original_shape_Maximum2DDiameterSlice', 'original_gldm_LargeDependenceEmphasis', 'original_glcm_Imc1', 'original_firstorder_Entropy', 'original_glszm_SmallAreaEmphasis', 'diagnostics_Mask-original_VoxelNum', 'original_shape_SurfaceVolumeRatio', 'original_glcm_DifferenceVariance', 'original_gldm_LargeDependenceLowGrayLevelEmphasis', 'original_firstorder_Kurtosis', 'original_firstorder_Minimum', 'original_gldm_LargeDependenceHighGrayLevelEmphasis', 'original_shape_MinorAxisLength', 'original_glcm_Idn', 'original_glcm_ClusterProminence', 'original_ngtdm_Strength', 'original_glszm_LowGrayLevelZoneEmphasis', 'original_glszm_SizeZoneNonUniformityNormalized', 'original_glrlm_RunPercentag
# ...

# %%
xgb_top50_features=lines
xgb_top50_features
# Out:
# ['original_firstorder_10Percentile',
#  'original_glrlm_RunLengthNonUniformity',
#  'original_glszm_SmallAreaHighGrayLevelEmphasis',
#  'original_firstorder_Range',
#  'original_glrlm_GrayLevelNonUniformityNormalized',
#  'original_glcm_Imc2',
#  'original_glszm_SizeZoneNonUniformity',
#  'diagnostics_Mask-original_VolumeNum',
#  'original_shape_Maximum2DDiameterSlice',
#  'original_gldm_LargeDependenceEmphasis',
#  'original_glcm_Imc1',
#  'original_firstorder_Entropy',
#  'original_glszm_SmallAreaEmphasis',
#  'diagnostics_Mask-original_VoxelNum',
#  'original_shape_SurfaceVolumeRatio',
#  'original_glcm_DifferenceVariance',
#  'original_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'original_firstorder_Kurtosis',
#  'original_firstorder_Minimum',
#  'original_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'original_shape_MinorAxisLength',
#  'original_glcm_Idn',
#  'original_glcm_ClusterProminence',
#  'original_ngtdm_Strength',
#  'original_glszm_LowGrayLevelZoneEmphasis',
# ...

# %%
test_top50_xgb=test_final.filter(items=xgb_top50_features)
test_top50_xgb
# Out:
#     original_firstorder_10Percentile  original_glrlm_RunLengthNonUniformity  \
# 0                          -0.184067                              -0.556634
# 1                          -0.426650                              -0.593809
# 2                          -0.669232                               0.169469
# 3                          -0.378133                              -0.117212
# 4                          -0.364271                               1.571215
# ..                               ...                                    ...
# 59                         -0.731611                              -0.601236
# 60                         -0.308824                              -0.209472
# 61                         -0.572199                              -0.419079
# 62                         -0.135550                              -1.051251
# 63                          0.217928                               0.029114
#
# ...

# %% [markdown]
# # 2) Test the Rembrandt Data

# %% [markdown]
# ## 2-1) SVM

# %%
# import trained svm model
import pickle
import joblib

svm_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_svm_classifier.pkl'

try:
    # Load the model using joblib
    svm_model = joblib.load(svm_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.svm import SVC

svm_predictions=svm_model.predict(test_final)
svm_results=pd.DataFrame({'id': test['id'], 'Prediction': svm_predictions})
svm_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-2) Random Forest

# %%
# import trained rf model

rf_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_rf_classifier.pkl'

try:
    # Load the model using joblib
    rf_model = joblib.load(rf_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.ensemble import RandomForestClassifier

rf_predictions=rf_model.predict(test_final)
rf_results=pd.DataFrame({'id': test['id'], 'Prediction': rf_predictions})
rf_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
# import trained dt model

dt_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_dt_classifier.pkl'

try:
    # Load the model using joblib
    dt_model = joblib.load(dt_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
 # This is dt top 30 used on random forest model!!

rf_predictions_dttop30=dt_model.predict(test_top30_dt)
rf_results_dttop30=pd.DataFrame({'id': test['id'], 'Prediction': rf_predictions_dttop30})
rf_results_dttop30
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           1
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-3) XGBoost

# %%
# import trained xgb model

xgb_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_xgb_classifier.pkl'

try:
    # Load the model using joblib
    xgb_model = joblib.load(xgb_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
import xgboost as xgb

xgb_predictions=xgb_model.predict(test_final)
xgb_results=pd.DataFrame({'id': test['id'], 'Prediction': xgb_predictions})
xgb_results
# Out:
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           0
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
import joblib

xgb_path='/content/drive/MyDrive/HIDS_7009/7009_Project/xgb_classifier.pkl'

try:
    # Load the model using joblib
    xgb_model = joblib.load(xgb_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
import xgboost as xgb

xgb_predictions=xgb_model.predict(test_final)
xgb_results=pd.DataFrame({'id': test['id'], 'Prediction': xgb_predictions})
xgb_results
# Out:
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           0
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
xgb_path='/content/drive/MyDrive/HIDS_7009/7009_Project/xgb_classifier_top50.pkl'

try:
    # Load the model using joblib
    xgb_model = joblib.load(xgb_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
import xgboost as xgb

xgb_predictions=xgb_model.predict(test_top50_xgb)
xgb_results=pd.DataFrame({'id': test['id'], 'Prediction': xgb_predictions})
xgb_results
# Out:
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           0
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
xgb_path='/content/drive/MyDrive/HIDS_7009/7009_Project/xgb_classifier_top50_resampled.pkl'

try:
    # Load the model using joblib
    xgb_model = joblib.load(xgb_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
xgb_predictions=xgb_model.predict(test_top50_xgb)
xgb_results=pd.DataFrame({'id': test['id'], 'Prediction': xgb_predictions})
xgb_results
# Out:
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           1
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-4) Decision Tree

# %%
# import trained dt model

dt_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_dt_classifier_2.pkl'

try:
    # Load the model using joblib
    dt_model_2 = joblib.load(dt_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.tree import DecisionTreeClassifier

dt_predictions=dt_model_2.predict(test_top30_dt)
dt_results=pd.DataFrame({'id': test['id'], 'Prediction': dt_predictions})
dt_results
# Out:
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           0
# 4   HF0920           0
# ..     ...         ...
# 59  HF1587           1
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           0
#
# [64 rows x 2 columns]

# %%
import joblib
dt_path='/content/drive/MyDrive/HIDS_7009/7009_Project/dt_classifier_trained.pkl'

try:
    # Load the model using joblib
    dt_model = joblib.load(dt_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.tree import DecisionTreeClassifier

dt_predictions=dt_model.predict(test_final)
dt_results=pd.DataFrame({'id': test['id'], 'Prediction': dt_predictions})
dt_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           0
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           1
# 4   HF0920           0
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-5) KNN

# %%
# import trained KNN model

knn_path='/content/drive/MyDrive/HIDS_7009/7009_Project/knn_classifier_scaled.pkl'

try:
    # Load the model using joblib
    knn_model = joblib.load(knn_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_predictions=knn_model.predict(test_final)
knn_results=pd.DataFrame({'id': test['id'], 'Prediction': knn_predictions})
knn_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           0
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           2
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-6) Adaboost

# %%
# import trained adaboost model

adaboost_path='/content/drive/MyDrive/HIDS_7009/7009_Project/naive_bayes.pkl'

try:
    # Load the model using joblib
    adaboost_model = joblib.load(adaboost_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.ensemble import AdaBoostClassifier

adaboost_predictions=adaboost_model.predict(test_final)
adaboost_results=pd.DataFrame({'id': test['id'], 'Prediction': adaboost_predictions})
adaboost_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           0
# 2   HF1078           2
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           2
# 62  HF1517           0
# 63  HF1560           2
#
# [64 rows x 2 columns]

# %%
# import trained adaboost model

adaboost_path2='/content/drive/MyDrive/HIDS_7009/7009_Project/best_adaboost_classifier2.pkl'

try:
    # Load the model using joblib
    adaboost_model2 = joblib.load(adaboost_path2)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
adaboost_predictions2=adaboost_model2.predict(test_final)
adaboost_results2=pd.DataFrame({'id': test['id'], 'Prediction': adaboost_predictions2})
adaboost_results2
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but AdaBoostClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
adaboost_path30='/content/drive/MyDrive/HIDS_7009/7009_Project/best_adaboost_classifier30.pkl'

try:
    # Load the model using joblib
    adaboost_model30 = joblib.load(adaboost_path30)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
adaboost_predictions30=adaboost_model30.predict(test_top30_dt)
adaboost_results30=pd.DataFrame({'id': test['id'], 'Prediction': adaboost_predictions30})
adaboost_results30
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-243-15aa92dcdae0> in <cell line: 1>()
# ----> 1 adaboost_predictions30=adaboost_model30.predict(test_top30_dt)
#       2 adaboost_results30=pd.DataFrame({'id': test['id'], 'Prediction': adaboost_predictions30})
#       3 adaboost_results30
#
# NameError: name 'test_top30_dt' is not defined

# %%
from sklearn.ensemble import AdaBoostClassifier

adaboost_path30='/content/drive/MyDrive/HIDS_7009/7009_Project/best_adaboost_classifier30.pkl'

try:
    # Load the model using joblib
    adaboost_model30 = joblib.load(adaboost_path30)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
adaboost_predictions30=adaboost_model30.predict(test_final)
adaboost_results30=pd.DataFrame({'id': test['id'], 'Prediction': adaboost_predictions30})
adaboost_results30
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but AdaBoostClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-7) Gradient Boosting Classifier

# %%
# import trained gb model

gb_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_gb_classifier.pkl'

try:
    # Load the model using joblib
    gb_model = joblib.load(gb_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_predictions=gb_model.predict(test_final)
gb_results=pd.DataFrame({'id': test['id'], 'Prediction': gb_predictions})
gb_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           0
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-8) Extra Trees Classifier

# %%
# import trained extra trees model

extra_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_extra_classifier.pkl'

try:
    # Load the model using joblib
    extra_model = joblib.load(extra_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.ensemble import ExtraTreesClassifier
extra_predictions=extra_model.predict(test_final)
extra_results=pd.DataFrame({'id': test['id'], 'Prediction': extra_predictions})
extra_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but ExtraTreesClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           1
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           1
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-9) Logistic Regression

# %%
# import trained logistic regression model

lr_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_lr_classifier.pkl'

try:
    # Load the model using joblib
    lr_model = joblib.load(lr_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.linear_model import LogisticRegression
lr_predictions=lr_model.predict(test_final)
lr_results=pd.DataFrame({'id': test['id'], 'Prediction': lr_predictions})
lr_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
lr_path_2='/content/drive/MyDrive/HIDS_7009/7009_Project/best_lr_classifier_2.pkl'

try:
    # Load the model using joblib
    lr_model = joblib.load(lr_path_2)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.linear_model import LogisticRegression
lr_predictions=lr_model.predict(test_top30_dt)
lr_results=pd.DataFrame({'id': test['id'], 'Prediction': lr_predictions})
lr_results
# Out:
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           0
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-10) Stacking

# %%
# import trained stacking model

stacking_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_stacking_classifier.pkl'

try:
    # Load the model using joblib
    stacking_model = joblib.load(stacking_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.ensemble import StackingClassifier

from sklearn.ensemble import StackingClassifier
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
stacking_predictions=stacking_model.predict(test_top50_xgb)
stacking_results=pd.DataFrame({'id': test['id'], 'Prediction': stacking_predictions})
stacking_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# ## 2-11) Voting Classifier

# %%
voting_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_voting_classifier.pkl'

try:
    # Load the model using joblib
    voting_model = joblib.load(voting_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.ensemble import VotingClassifier
voting_predictions=voting_model.predict(test_final)
voting_results=pd.DataFrame({'id': test['id'], 'Prediction': voting_predictions})
voting_results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           0
# 4   HF0920           0
# ..     ...         ...
# 59  HF1587           1
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
voting_top30_path='/content/drive/MyDrive/HIDS_7009/7009_Project/best_voting_top30_classifier.pkl'

try:
    # Load the model using joblib
    voting_top30_model = joblib.load(voting_top30_path)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
voting_predictions_top30=voting_top30_model.predict(test_top30_dt)
voting_results_top30=pd.DataFrame({'id': test['id'], 'Prediction': voting_predictions_top30})
voting_results_top30
# Out:
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           0
# 2   HF1078           0
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           1
# 60  HF1551           0
# 61  HF1538           0
# 62  HF1517           0
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
voting_3='/content/drive/MyDrive/HIDS_7009/7009_Project/best_voting_3.pkl'

try:
    # Load the model using joblib
    voting_top30_model_3 = joblib.load(voting_3)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
voting_predictions_3=voting_top30_model_3.predict(test_final)
voting_results_3=pd.DataFrame({'id': test['id'], 'Prediction': voting_predictions_3})
voting_results_3
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but AdaBoostClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           0
# 4   HF0920           1
# ..     ...         ...
# 59  HF1587           1
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
voting_4='/content/drive/MyDrive/HIDS_7009/7009_Project/best_voting_4.pkl'

try:
    # Load the model using joblib
    voting_top30_model_4 = joblib.load(voting_4)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
voting_predictions_4=voting_top30_model_4.predict(test_top50_xgb)
voting_results_4=pd.DataFrame({'id': test['id'], 'Prediction': voting_predictions_4})
voting_results_4
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but AdaBoostClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           1
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           2
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
import joblib
voting_5='/content/drive/MyDrive/HIDS_7009/7009_Project/best_voting_5.pkl'

try:
    # Load the model using joblib
    voting_top30_model_5 = joblib.load(voting_5)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
from sklearn.ensemble import VotingClassifier
voting_predictions_5=voting_top30_model_5.predict(test_final)
voting_results_5=pd.DataFrame({'id': test['id'], 'Prediction': voting_predictions_5})
voting_results_5
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           1
# 4   HF0920           0
# ..     ...         ...
# 59  HF1587           1
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           0
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %%
voting_6='/content/drive/MyDrive/HIDS_7009/7009_Project/best_voting_6.pkl'

try:
    # Load the model using joblib
    voting_top30_model_6 = joblib.load(voting_6)
    print("Model loaded successfully!")
except FileNotFoundError as e:
    print("Error loading model:", e)
# Out:
# Model loaded successfully!

# %%
voting_predictions_6=voting_top30_model_6.predict(test_top30_dt)
voting_results_6=pd.DataFrame({'id': test['id'], 'Prediction': voting_predictions_6})
voting_results_6
# Out:
#         id  Prediction
# 0   HF1097           1
# 1   HF1150           1
# 2   HF1078           1
# 3   HF1000           2
# 4   HF0920           2
# ..     ...         ...
# 59  HF1587           1
# 60  HF1551           1
# 61  HF1538           1
# 62  HF1517           1
# 63  HF1560           1
#
# [64 rows x 2 columns]

# %% [markdown]
# # **TASK 4**

# %% [markdown]
# # 1) Import ground truth data and process for comparison

# %%
file_path='/content/drive/MyDrive/HIDS_7009/7009_Project/Rembrandt_Clinical_ground_truth_64set.txt'
with open(file_path, "r") as file:
  lines=file.read().splitlines()

print(lines)
# Out:
# ['64.patient.set\tAGE_RANGE\tGENDER\tDISEASE_TYPE', '900_00_5299\t\t\t', '900_00_5303\t\t\t', '900_00_5308\t\t \tASTROCYTOMA', '900_00_5316\t\t \tGBM', '900_00_5317\t\t \tGBM', '900_00_5332\t\t \tGBM', '900_00_5341\t\t \tOLIGODENDROGLIOMA', '900_00_5342\t\t \tGBM', '900_00_5346\t\t \tGBM', '900_00_5380\t\t \tOLIGODENDROGLIOMA', '900_00_5381\t\t \tGBM', '900_00_5385\t\t \tASTROCYTOMA', '900_00_5396\t\t \tGBM', '900_00_5404\t\t \tGBM', '900_00_5412\t\t \tOLIGODENDROGLIOMA', '900_00_5414\t\t \tGBM', '900_00_5459\t\t \tASTROCYTOMA', '900_00_5462\t\t \tGBM', '900_00_5476\t\t \tOLIGODENDROGLIOMA', '900_00_5477\t\t \tASTROCYTOMA', 'HF0763\t\t\t', 'HF0835\t35-39\tFEMALE\tOLIGODENDROGLIOMA', 'HF0855\t55-59\tMALE\tASTROCYTOMA', 'HF0899\t55-59\tMALE\tASTROCYTOMA', 'HF0920\t85-89\tFEMALE\tOLIGODENDROGLIOMA', 'HF1000\t30-34\tMALE\tASTROCYTOMA', 'HF1078\t45-49\tMALE\tGBM', 'HF1097\t50-54\tFEMALE\tGBM', 'HF1150\t70-74\tMALE\tASTROCYTOMA', 'HF1156\t30-34\tFEMALE\tASTROCYTOMA', 'HF1167\t45-49\tMALE\t
# ...

# %%
truth=lines

# %%
truth
# Out:
# ['64.patient.set\tAGE_RANGE\tGENDER\tDISEASE_TYPE',
#  '900_00_5299\t\t\t',
#  '900_00_5303\t\t\t',
#  '900_00_5308\t\t \tASTROCYTOMA',
#  '900_00_5316\t\t \tGBM',
#  '900_00_5317\t\t \tGBM',
#  '900_00_5332\t\t \tGBM',
#  '900_00_5341\t\t \tOLIGODENDROGLIOMA',
#  '900_00_5342\t\t \tGBM',
#  '900_00_5346\t\t \tGBM',
#  '900_00_5380\t\t \tOLIGODENDROGLIOMA',
#  '900_00_5381\t\t \tGBM',
#  '900_00_5385\t\t \tASTROCYTOMA',
#  '900_00_5396\t\t \tGBM',
#  '900_00_5404\t\t \tGBM',
#  '900_00_5412\t\t \tOLIGODENDROGLIOMA',
#  '900_00_5414\t\t \tGBM',
#  '900_00_5459\t\t \tASTROCYTOMA',
#  '900_00_5462\t\t \tGBM',
#  '900_00_5476\t\t \tOLIGODENDROGLIOMA',
#  '900_00_5477\t\t \tASTROCYTOMA',
#  'HF0763\t\t\t',
#  'HF0835\t35-39\tFEMALE\tOLIGODENDROGLIOMA',
#  'HF0855\t55-59\tMALE\tASTROCYTOMA',
#  'HF0899\t55-59\tMALE\tASTROCYTOMA',
#  'HF0920\t85-89\tFEMALE\tOLIGODENDROGLIOMA',
#  'HF1000\t30-34\tMALE\tASTROCYTOMA',
#  'HF1078\t45-49\tMALE\tGBM',
#  'HF1097\t50-54\tFEMALE\tGBM',
# ...

# %%
test_truth=pd.read_csv('/content/drive/MyDrive/HIDS_7009/7009_Project/Rembrandt_Clinical_ground_truth_64set.txt', sep='\t')
test_truth
# Out:
#    64.patient.set AGE_RANGE  GENDER       DISEASE_TYPE
# 0     900_00_5299       NaN     NaN                NaN
# 1     900_00_5303       NaN     NaN                NaN
# 2     900_00_5308       NaN                ASTROCYTOMA
# 3     900_00_5316       NaN                        GBM
# 4     900_00_5317       NaN                        GBM
# ..            ...       ...     ...                ...
# 59         HF1606     60-64    MALE        ASTROCYTOMA
# 60         HF1613     35-39    MALE        ASTROCYTOMA
# 61         HF1652       NaN     NaN                NaN
# 62         HF1677     50-54    MALE        ASTROCYTOMA
# 63         HF1702     75-79  FEMALE  OLIGODENDROGLIOMA
#
# [64 rows x 4 columns]

# %%
test_truth.drop(['AGE_RANGE', 'GENDER'], axis=1, inplace=True)

# %%
test_truth
# Out:
#    64.patient.set       DISEASE_TYPE
# 0     900_00_5299                NaN
# 1     900_00_5303                NaN
# 2     900_00_5308        ASTROCYTOMA
# 3     900_00_5316                GBM
# 4     900_00_5317                GBM
# ..            ...                ...
# 59         HF1606        ASTROCYTOMA
# 60         HF1613        ASTROCYTOMA
# 61         HF1652                NaN
# 62         HF1677        ASTROCYTOMA
# 63         HF1702  OLIGODENDROGLIOMA
#
# [64 rows x 2 columns]

# %%
disease_type_mapping = {
    'GBM': 1,
    'ASTROCYTOMA': 0,
    'OLIGODENDROGLIOMA': 2
}

# %%
test_truth['DISEASE_TYPE'] = test_truth['DISEASE_TYPE'].map(disease_type_mapping)

# %%
test_truth
# Out:
#    64.patient.set  DISEASE_TYPE
# 0     900_00_5299           NaN
# 1     900_00_5303           NaN
# 2     900_00_5308           0.0
# 3     900_00_5316           1.0
# 4     900_00_5317           1.0
# ..            ...           ...
# 59         HF1606           0.0
# 60         HF1613           0.0
# 61         HF1652           NaN
# 62         HF1677           0.0
# 63         HF1702           2.0
#
# [64 rows x 2 columns]

# %%
test_truth.dropna(inplace=True)
test_truth['DISEASE_TYPE'] = test_truth['DISEASE_TYPE'].astype(int)
test_truth
# Out:
#    64.patient.set  DISEASE_TYPE
# 2     900_00_5308             0
# 3     900_00_5316             1
# 4     900_00_5317             1
# 5     900_00_5332             1
# 6     900_00_5341             2
# 7     900_00_5342             1
# 8     900_00_5346             1
# 9     900_00_5380             2
# 10    900_00_5381             1
# 11    900_00_5385             0
# 12    900_00_5396             1
# 13    900_00_5404             1
# 14    900_00_5412             2
# 15    900_00_5414             1
# 16    900_00_5459             0
# 17    900_00_5462             1
# 18    900_00_5476             2
# 19    900_00_5477             0
# 21         HF0835             2
# 22         HF0855             0
# 23         HF0899             0
# 24         HF0920             2
# 25         HF1000             0
# 26         HF1078             1
# 27         HF1097             1
# 28         HF1150             0
# 29         HF1156             0
# 30         HF1167             2
# ...

# %%
test_truth['64.patient.set']=test_truth['64.patient.set'].str.replace('_','-')
test_truth
# Out:
#    64.patient.set  DISEASE_TYPE
# 2     900-00-5308             0
# 3     900-00-5316             1
# 4     900-00-5317             1
# 5     900-00-5332             1
# 6     900-00-5341             2
# 7     900-00-5342             1
# 8     900-00-5346             1
# 9     900-00-5380             2
# 10    900-00-5381             1
# 11    900-00-5385             0
# 12    900-00-5396             1
# 13    900-00-5404             1
# 14    900-00-5412             2
# 15    900-00-5414             1
# 16    900-00-5459             0
# 17    900-00-5462             1
# 18    900-00-5476             2
# 19    900-00-5477             0
# 21         HF0835             2
# 22         HF0855             0
# 23         HF0899             0
# 24         HF0920             2
# 25         HF1000             0
# 26         HF1078             1
# 27         HF1097             1
# 28         HF1150             0
# 29         HF1156             0
# 30         HF1167             2
# ...

# %%
counts = test_truth['DISEASE_TYPE'].value_counts()

print(counts)
# Out:
# DISEASE_TYPE
# 0    28
# 1    18
# 2    12
# Name: count, dtype: int64

# %%
test_truth.shape
# Out:
# (58, 2)

# %% [markdown]
# # 2) Compare results & Classification report

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# ## 2-1) SVM

# %%
svm_results_merged=svm_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
svm_results_merged
# Out:
#         id  Prediction 64.patient.set  DISEASE_TYPE
# 0   HF1097           1         HF1097           1.0
# 1   HF1150           1         HF1150           0.0
# 2   HF1078           1         HF1078           1.0
# 3   HF1000           2         HF1000           0.0
# 4   HF0920           2         HF0920           2.0
# ..     ...         ...            ...           ...
# 59  HF1587           2         HF1587           0.0
# 60  HF1551           1         HF1551           0.0
# 61  HF1538           1         HF1538           1.0
# 62  HF1517           1         HF1517           1.0
# 63  HF1560           1         HF1560           1.0
#
# [64 rows x 4 columns]

# %%
svm_results_final=svm_results_merged.drop(columns=['64.patient.set'])
svm_results_final=svm_results_final.dropna()
svm_results_final=svm_results_final.reset_index(drop=True)
svm_results_final
# Out:
#              id  Prediction  DISEASE_TYPE
# 0        HF1097           1           1.0
# 1        HF1150           1           0.0
# 2        HF1078           1           1.0
# 3        HF1000           2           0.0
# 4        HF0920           2           2.0
# 5        HF0855           0           0.0
# 6   900-00-5477           0           0.0
# 7        HF0899           2           0.0
# 8        HF0835           2           2.0
# 9        HF1280           1           0.0
# 10       HF1292           1           1.0
# 11       HF1191           1           1.0
# 12       HF1246           1           0.0
# 13       HF1156           2           0.0
# 14       HF1219           1           2.0
# 15       HF1167           1           2.0
# 16       HF1185           1           0.0
# 17       HF1235           2           0.0
# 18       HF1409           1           0.0
# 19       HF1345           1           0.0
# 20       HF1381           2           0.0
# ...

# %%
svm_results_final['DISEASE_TYPE']=svm_results_final['DISEASE_TYPE'].astype(int)
svm_results_final
# Out:
#              id  Prediction  DISEASE_TYPE
# 0        HF1097           1             1
# 1        HF1150           1             0
# 2        HF1078           1             1
# 3        HF1000           2             0
# 4        HF0920           2             2
# 5        HF0855           0             0
# 6   900-00-5477           0             0
# 7        HF0899           2             0
# 8        HF0835           2             2
# 9        HF1280           1             0
# 10       HF1292           1             1
# 11       HF1191           1             1
# 12       HF1246           1             0
# 13       HF1156           2             0
# 14       HF1219           1             2
# 15       HF1167           1             2
# 16       HF1185           1             0
# 17       HF1235           2             0
# 18       HF1409           1             0
# 19       HF1345           1             0
# 20       HF1381           2             0
# ...

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

y_pred = svm_results_final['Prediction']
y_true = svm_results_final['DISEASE_TYPE']

report = classification_report(y_true, y_pred)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.21      0.29        28
#            1       0.46      0.72      0.57        18
#            2       0.19      0.25      0.21        12
#
#     accuracy                           0.38        58
#    macro avg       0.36      0.40      0.36        58
# weighted avg       0.39      0.38      0.36        58

# %% [markdown]
# ## 2-2) Random Forest

# %%
rf_results_merged=rf_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
rf_results_final=rf_results_merged.drop(columns=['64.patient.set'])
rf_results_final=rf_results_final.dropna()
rf_results_final=rf_results_final.reset_index(drop=True)
rf_results_final['DISEASE_TYPE']=rf_results_final['DISEASE_TYPE'].astype(int)
y_pred = rf_results_final['Prediction']
y_true = rf_results_final['DISEASE_TYPE']

report = classification_report(y_true, y_pred)
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.07      0.12        28
#            1       0.42      0.89      0.57        18
#            2       0.21      0.25      0.23        12
#
#     accuracy                           0.36        58
#    macro avg       0.32      0.40      0.31        58
# weighted avg       0.34      0.36      0.28        58

# %%
rf2_results_merged=rf_results_dttop30.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
rf2_results_final=rf2_results_merged.drop(columns=['64.patient.set'])
rf2_results_final=rf2_results_final.dropna()
rf2_results_final=rf2_results_final.reset_index(drop=True)
rf2_results_final['DISEASE_TYPE']=rf2_results_final['DISEASE_TYPE'].astype(int)
y_pred = rf2_results_final['Prediction']
y_true = rf2_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.07      0.11        28
#            1       0.38      0.83      0.53        18
#            2       0.18      0.17      0.17        12
#
#     accuracy                           0.33        58
#    macro avg       0.27      0.36      0.27        58
# weighted avg       0.28      0.33      0.25        58

# %% [markdown]
# ## 2-3) XGBoost

# %%
xgb_results_merged=xgb_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
xgb_results_final=xgb_results_merged.drop(columns=['64.patient.set'])
xgb_results_final=xgb_results_final.dropna()
xgb_results_final=xgb_results_final.reset_index(drop=True)
xgb_results_final['DISEASE_TYPE']=xgb_results_final['DISEASE_TYPE'].astype(int)
y_pred = xgb_results_final['Prediction']
y_true = xgb_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.14      0.22        28
#            1       0.39      0.83      0.54        18
#            2       0.25      0.25      0.25        12
#
#     accuracy                           0.38        58
#    macro avg       0.38      0.41      0.34        58
# weighted avg       0.42      0.38      0.33        58

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

xgb_results_merged=xgb_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
xgb_results_final=xgb_results_merged.drop(columns=['64.patient.set'])
xgb_results_final=xgb_results_final.dropna()
xgb_results_final=xgb_results_final.reset_index(drop=True)
xgb_results_final['DISEASE_TYPE']=xgb_results_final['DISEASE_TYPE'].astype(int)
y_pred = xgb_results_final['Prediction']
y_true = xgb_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.14      0.22        28
#            1       0.39      0.83      0.54        18
#            2       0.25      0.25      0.25        12
#
#     accuracy                           0.38        58
#    macro avg       0.38      0.41      0.34        58
# weighted avg       0.42      0.38      0.33        58

# %%
xgb_results_merged=xgb_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
xgb_results_final=xgb_results_merged.drop(columns=['64.patient.set'])
xgb_results_final=xgb_results_final.dropna()
xgb_results_final=xgb_results_final.reset_index(drop=True)
xgb_results_final['DISEASE_TYPE']=xgb_results_final['DISEASE_TYPE'].astype(int)
y_pred = xgb_results_final['Prediction']
y_true = xgb_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.21      0.32        28
#            1       0.44      0.89      0.59        18
#            2       0.25      0.25      0.25        12
#
#     accuracy                           0.43        58
#    macro avg       0.43      0.45      0.39        58
# weighted avg       0.48      0.43      0.39        58

# %%
xgb_results_merged=xgb_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
xgb_results_final=xgb_results_merged.drop(columns=['64.patient.set'])
xgb_results_final=xgb_results_final.dropna()
xgb_results_final=xgb_results_final.reset_index(drop=True)
xgb_results_final['DISEASE_TYPE']=xgb_results_final['DISEASE_TYPE'].astype(int)
y_pred = xgb_results_final['Prediction']
y_true = xgb_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.07      0.12        28
#            1       0.42      0.83      0.56        18
#            2       0.25      0.33      0.29        12
#
#     accuracy                           0.36        58
#    macro avg       0.33      0.41      0.32        58
# weighted avg       0.34      0.36      0.29        58

# %% [markdown]
# ## 2-4) Decision Tree

# %%
dt_results_merged=dt_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
dt_results_final=dt_results_merged.drop(columns=['64.patient.set'])
dt_results_final=dt_results_final.dropna()
dt_results_final=dt_results_final.reset_index(drop=True)
dt_results_final['DISEASE_TYPE']=dt_results_final['DISEASE_TYPE'].astype(int)
y_pred =dt_results_final['Prediction']
y_true = dt_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.18      0.22        28
#            1       0.35      0.72      0.47        18
#            2       0.00      0.00      0.00        12
#
#     accuracy                           0.31        58
#    macro avg       0.22      0.30      0.23        58
# weighted avg       0.25      0.31      0.25        58

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import seaborn as sns
dt_results_merged=dt_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
dt_results_final=dt_results_merged.drop(columns=['64.patient.set'])
dt_results_final=dt_results_final.dropna()
dt_results_final=dt_results_final.reset_index(drop=True)
dt_results_final['DISEASE_TYPE']=dt_results_final['DISEASE_TYPE'].astype(int)
y_pred =dt_results_final['Prediction']
y_true = dt_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.18      0.25        28
#            1       0.33      0.78      0.47        18
#            2       0.25      0.08      0.12        12
#
#     accuracy                           0.34        58
#    macro avg       0.33      0.35      0.28        58
# weighted avg       0.36      0.34      0.29        58

# %% [markdown]
# ## 2-5) KNN

# %%
knn_results_merged=knn_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
knn_results_final=knn_results_merged.drop(columns=['64.patient.set'])
knn_results_final=knn_results_final.dropna()
knn_results_final=knn_results_final.reset_index(drop=True)
knn_results_final['DISEASE_TYPE']=knn_results_final['DISEASE_TYPE'].astype(int)
y_pred =knn_results_final['Prediction']
y_true = knn_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.21      0.28        28
#            1       0.50      0.61      0.55        18
#            2       0.24      0.42      0.30        12
#
#     accuracy                           0.38        58
#    macro avg       0.38      0.41      0.38        58
# weighted avg       0.40      0.38      0.37        58

# %% [markdown]
# ## 2-6) Adaboost

# %%
adaboost_results_merged=adaboost_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
adaboost_results_final=adaboost_results_merged.drop(columns=['64.patient.set'])
adaboost_results_final=adaboost_results_final.dropna()
adaboost_results_final=adaboost_results_final.reset_index(drop=True)
adaboost_results_final['DISEASE_TYPE']=adaboost_results_final['DISEASE_TYPE'].astype(int)
y_pred =adaboost_results_final['Prediction']
y_true = adaboost_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.35      0.29      0.31        28
#            1       0.40      0.11      0.17        18
#            2       0.20      0.50      0.29        12
#
#     accuracy                           0.28        58
#    macro avg       0.32      0.30      0.26        58
# weighted avg       0.33      0.28      0.26        58

# %%
adaboost_results_merged2=adaboost_results2.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
adaboost_results_final2=adaboost_results_merged2.drop(columns=['64.patient.set'])
adaboost_results_final2=adaboost_results_final2.dropna()
adaboost_results_final2=adaboost_results_final2.reset_index(drop=True)
adaboost_results_final2['DISEASE_TYPE']=adaboost_results_final2['DISEASE_TYPE'].astype(int)
y_pred =adaboost_results_final2['Prediction']
y_true = adaboost_results_final2['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.07      0.12        28
#            1       0.42      0.89      0.57        18
#            2       0.21      0.25      0.23        12
#
#     accuracy                           0.36        58
#    macro avg       0.32      0.40      0.31        58
# weighted avg       0.34      0.36      0.28        58

# %%
adaboost_results_merged30=adaboost_results30.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
adaboost_results_final30=adaboost_results_merged30.drop(columns=['64.patient.set'])
adaboost_results_final30=adaboost_results_final30.dropna()
adaboost_results_final30=adaboost_results_final30.reset_index(drop=True)
adaboost_results_final30['DISEASE_TYPE']=adaboost_results_final30['DISEASE_TYPE'].astype(int)
y_pred =adaboost_results_final30['Prediction']
y_true = adaboost_results_final30['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.20      0.04      0.06        28
#            1       0.44      0.89      0.59        18
#            2       0.24      0.33      0.28        12
#
#     accuracy                           0.36        58
#    macro avg       0.29      0.42      0.31        58
# weighted avg       0.28      0.36      0.27        58

# %%
adaboost_results_merged30=adaboost_results30.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
adaboost_results_final30=adaboost_results_merged30.drop(columns=['64.patient.set'])
adaboost_results_final30=adaboost_results_final30.dropna()
adaboost_results_final30=adaboost_results_final30.reset_index(drop=True)
adaboost_results_final30['DISEASE_TYPE']=adaboost_results_final30['DISEASE_TYPE'].astype(int)
y_pred =adaboost_results_final30['Prediction']
y_true = adaboost_results_final30['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.20      0.04      0.06        28
#            1       0.44      0.89      0.59        18
#            2       0.24      0.33      0.28        12
#
#     accuracy                           0.36        58
#    macro avg       0.29      0.42      0.31        58
# weighted avg       0.28      0.36      0.27        58

# %% [markdown]
# ## 2-7) Gradient Boosting

# %%
gb_results_merged=gb_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
gb_results_final=gb_results_merged.drop(columns=['64.patient.set'])
gb_results_final=gb_results_final.dropna()
gb_results_final=gb_results_final.reset_index(drop=True)
gb_results_final['DISEASE_TYPE']=gb_results_final['DISEASE_TYPE'].astype(int)
y_pred =gb_results_final['Prediction']
y_true = gb_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.32      0.43        28
#            1       0.44      0.94      0.60        18
#            2       0.60      0.25      0.35        12
#
#     accuracy                           0.50        58
#    macro avg       0.56      0.51      0.46        58
# weighted avg       0.57      0.50      0.47        58

# %% [markdown]
# ## 2-8) Extra Trees Classifier

# %%
extra_results_merged=extra_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
extra_results_final=extra_results_merged.drop(columns=['64.patient.set'])
extra_results_final=extra_results_final.dropna()
extra_results_final=extra_results_final.reset_index(drop=True)
extra_results_final['DISEASE_TYPE']=extra_results_final['DISEASE_TYPE'].astype(int)
y_pred =extra_results_final['Prediction']
y_true = extra_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.11      0.16        28
#            1       0.35      0.78      0.48        18
#            2       0.33      0.25      0.29        12
#
#     accuracy                           0.34        58
#    macro avg       0.34      0.38      0.31        58
# weighted avg       0.34      0.34      0.29        58

# %% [markdown]
# ## 2-9) Logistic Regression

# %%
lr_results_merged=lr_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
lr_results_final=lr_results_merged.drop(columns=['64.patient.set'])
lr_results_final=lr_results_final.dropna()
lr_results_final=lr_results_final.reset_index(drop=True)
lr_results_final['DISEASE_TYPE']=lr_results_final['DISEASE_TYPE'].astype(int)
y_pred =lr_results_final['Prediction']
y_true =lr_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.07      0.12        28
#            1       0.52      0.94      0.67        18
#            2       0.20      0.33      0.25        12
#
#     accuracy                           0.40        58
#    macro avg       0.37      0.45      0.35        58
# weighted avg       0.39      0.40      0.32        58

# %% [markdown]
# ## 2-10) Stacking

# %%
stacking_results_merged=stacking_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
stacking_results_final=stacking_results_merged.drop(columns=['64.patient.set'])
stacking_results_final=stacking_results_final.dropna()
stacking_results_final=stacking_results_final.reset_index(drop=True)
stacking_results_final['DISEASE_TYPE']=stacking_results_final['DISEASE_TYPE'].astype(int)
y_pred =stacking_results_final['Prediction']
y_true =stacking_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.04      0.06        28
#            1       0.45      1.00      0.62        18
#            2       0.36      0.42      0.38        12
#
#     accuracy                           0.41        58
#    macro avg       0.35      0.48      0.36        58
# weighted avg       0.33      0.41      0.30        58

# %% [markdown]
# ## 2-11) Voting Classifier

# %%
voting_results_merged=voting_results.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
voting_results_final=voting_results_merged.drop(columns=['64.patient.set'])
voting_results_final=voting_results_final.dropna()
voting_results_final=voting_results_final.reset_index(drop=True)
voting_results_final['DISEASE_TYPE']=voting_results_final['DISEASE_TYPE'].astype(int)
y_pred =voting_results_final['Prediction']
y_true =voting_results_final['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.21      0.27        28
#            1       0.34      0.78      0.47        18
#            2       0.00      0.00      0.00        12
#
#     accuracy                           0.34        58
#    macro avg       0.24      0.33      0.25        58
# weighted avg       0.29      0.34      0.28        58

# %%
voting_results_merged_top30=voting_results_top30.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
voting_results_final_top30=voting_results_merged_top30.drop(columns=['64.patient.set'])
voting_results_final_top30=voting_results_final_top30.dropna()
voting_results_final_top30=voting_results_final_top30.reset_index(drop=True)
voting_results_final_top30['DISEASE_TYPE']=voting_results_final_top30['DISEASE_TYPE'].astype(int)
y_pred =voting_results_final_top30['Prediction']
y_true =voting_results_final_top30['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.61      0.53        28
#            1       0.47      0.44      0.46        18
#            2       0.40      0.17      0.24        12
#
#     accuracy                           0.47        58
#    macro avg       0.45      0.41      0.41        58
# weighted avg       0.46      0.47      0.45        58

# %%
voting_results_merged_3=voting_results_3.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
voting_results_final_3=voting_results_merged_3.drop(columns=['64.patient.set'])
voting_results_final_3=voting_results_final_3.dropna()
voting_results_final_3=voting_results_final_3.reset_index(drop=True)
voting_results_final_3['DISEASE_TYPE']=voting_results_final_3['DISEASE_TYPE'].astype(int)
y_pred =voting_results_final_3['Prediction']
y_true =voting_results_final_3['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.21      0.32        28
#            1       0.38      1.00      0.55        18
#            2       0.00      0.00      0.00        12
#
#     accuracy                           0.41        58
#    macro avg       0.35      0.40      0.29        58
# weighted avg       0.44      0.41      0.33        58

# %%
voting_results_merged_4=voting_results_4.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
voting_results_final_4=voting_results_merged_4.drop(columns=['64.patient.set'])
voting_results_final_4=voting_results_final_4.dropna()
voting_results_final_4=voting_results_final_4.reset_index(drop=True)
voting_results_final_4['DISEASE_TYPE']=voting_results_final_4['DISEASE_TYPE'].astype(int)
y_pred =voting_results_final_4['Prediction']
y_true =voting_results_final_4['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.11      0.17        28
#            1       0.40      0.94      0.57        18
#            2       0.44      0.33      0.38        12
#
#     accuracy                           0.41        58
#    macro avg       0.43      0.46      0.37        58
# weighted avg       0.42      0.41      0.34        58

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
voting_results_merged_5=voting_results_5.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
voting_results_final_5=voting_results_merged_5.drop(columns=['64.patient.set'])
voting_results_final_5=voting_results_final_5.dropna()
voting_results_final_5=voting_results_final_5.reset_index(drop=True)
voting_results_final_5['DISEASE_TYPE']=voting_results_final_5['DISEASE_TYPE'].astype(int)
y_pred =voting_results_final_5['Prediction']
y_true =voting_results_final_5['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.29      0.36        28
#            1       0.39      0.83      0.54        18
#            2       0.50      0.17      0.25        12
#
#     accuracy                           0.43        58
#    macro avg       0.46      0.43      0.38        58
# weighted avg       0.47      0.43      0.39        58

# %%
voting_results_merged_6=voting_results_6.merge(test_truth, left_on='id', right_on='64.patient.set', how='left')
voting_results_final_6=voting_results_merged_6.drop(columns=['64.patient.set'])
voting_results_final_6=voting_results_final_6.dropna()
voting_results_final_6=voting_results_final_6.reset_index(drop=True)
voting_results_final_6['DISEASE_TYPE']=voting_results_final_6['DISEASE_TYPE'].astype(int)
y_pred =voting_results_final_6['Prediction']
y_true =voting_results_final_6['DISEASE_TYPE']
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.11      0.15        28
#            1       0.34      0.78      0.47        18
#            2       0.17      0.08      0.11        12
#
#     accuracy                           0.31        58
#    macro avg       0.26      0.32      0.25        58
# weighted avg       0.27      0.31      0.24        58

# %% [markdown]
# # SUMMARY OF FINDING

# %% [markdown]
# - Overall, the model performance was not as expected compared to the training results on TCGA data set.
# - The highest performing model was the Voting Classifier, when top 30 features were used for prediction.
# - Interestingly, when training the models on TCGA data, classification 0 which is astrocytoma was the most difficult to classify, but when it was applied to Rembrandt dataset, it could classify astrocytoma the best among all the diagnoses.
